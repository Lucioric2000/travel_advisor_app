# %%
# !pip install pandas matplotlib
# Out:
# Requirement already satisfied: pandas in C:\Users\lucio\PycharmProjects\Turing\IA_learning\.venv\Lib\site-packages (3.0.3)
# Requirement already satisfied: matplotlib in C:\Users\lucio\PycharmProjects\Turing\IA_learning\.venv\Lib\site-packages (3.10.9)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\lucio\PycharmProjects\Turing\IA_learning\.venv\Lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\lucio\PycharmProjects\Turing\IA_learning\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\lucio\PycharmProjects\Turing\IA_learning\.venv\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\lucio\PycharmProjects\Turing\IA_learning\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\lucio\PycharmProjects\Turing\IA_learning\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\lucio\PycharmProjects\Turing\IA_learning\.venv\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\lucio\PycharmProjects\Turing\IA_learning\.venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\lucio\PycharmProjects\Turing\IA_learning\.venv\Lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in C:\Users\lucio\PycharmProjects\Turing\IA_learning\.venv\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\lucio\PycharmProjects\Turing\IA_learning\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in C:\Users\lucio\PycharmProjects\Turing\IA_learning\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
births = pd.read_csv('births.csv')
vc = births.value_counts('month')

# %%
vc
# Out:
# month
# 3     1310
# 8     1309
# 7     1308
# 12    1308
# 10    1308
# 1     1306
# 5     1305
# 11    1290
# 6     1288
# 9     1288
# 4     1287
# 2     1240
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
vc.plot()
plt.show()
